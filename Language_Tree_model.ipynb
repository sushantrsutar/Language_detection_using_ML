# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv('my_dataframe')
df2=pd.read_csv('bulgarian.csv')

df4=pd.read_csv('Telugu5.csv')
df=pd.read_csv('Danish.csv')
df5=pd.read_csv('Georgian.csv')
df6=pd.read_csv('German.csv')
df7=pd.read_csv('Greek.csv')
df8=pd.read_csv('Italian.csv')

df12=pd.read_csv('Kannada.csv')
df14=pd.read_csv('punjabi.csv')

df16=pd.read_csv('Tatar.csv')

# %%
df_final=pd.concat([df,df1,df2,df4,df5,df7,df8,df14,df16],axis=0)
df_final
# Out:
#                                                   Text Language  Unnamed: 2  \
# 0                                            Hverdagen  Danish          NaN
# 1                      hvorpå mennesker typisk handler  Danish          NaN
# 2            Hverdagen kan beskrives som hverdagsagtig  Danish          NaN
# 3                                         rutinemæssig  Danish          NaN
# 4                           Menneskelig dagtid betyder  Danish          NaN
# ..                                                 ...      ...         ...
# 951  [345] [346] эчтәлек җитештерүчеләрнең эштән ки...    Tatar         NaN
# 952  Карр язган: "Веб 2.0 экстатик күренешләрендә ү...    Tatar         NaN
# 953  Мин куркытырлык бернәрсә дә күз алдыма китерә ...    Tatar         NaN
# 954  [348] Башкалар Википедия, яки шундый ук тырышл...    Tatar         NaN
# 955  [349] Википедиянең биография нәшрият бизнесына...    Tatar         NaN
#
#     Unnamed: 3 ბუნება
# 0          NaN    NaN
# 1          NaN    NaN
# 2          NaN    NaN
# 3          NaN    NaN
# 4          NaN    NaN
# ..         ...    ...
# 951        NaN    NaN
# 952        NaN    NaN
# 953        NaN    NaN
# 954        NaN    NaN
# 955        NaN    NaN
#
# [33526 rows x 5 columns]

# %%
df_final=df_final.drop(columns=['ბუნება','Unnamed: 2','Unnamed: 3'])
df_final
# Out:
#                                                   Text Language
# 0                                            Hverdagen  Danish
# 1                      hvorpå mennesker typisk handler  Danish
# 2            Hverdagen kan beskrives som hverdagsagtig  Danish
# 3                                         rutinemæssig  Danish
# 4                           Menneskelig dagtid betyder  Danish
# ..                                                 ...      ...
# 951  [345] [346] эчтәлек җитештерүчеләрнең эштән ки...    Tatar
# 952  Карр язган: "Веб 2.0 экстатик күренешләрендә ү...    Tatar
# 953  Мин куркытырлык бернәрсә дә күз алдыма китерә ...    Tatar
# 954  [348] Башкалар Википедия, яки шундый ук тырышл...    Tatar
# 955  [349] Википедиянең биография нәшрият бизнесына...    Tatar
#
# [33526 rows x 2 columns]

# %%
#method to clean english 
import re
def remove_special_sym1(row):
    pattern=re.compile('[^\w\s]')
    pattern1=re.compile('[\d]')
    text=str(row['Text'])
    text=re.sub(pattern,'',text)
    text=re.sub(pattern1,'',text)
    return text

# %%
df_final['Text']=df_final.apply(remove_special_sym1,axis=1)
df_final.tail(30)
# Out:
#                                                   Text Language
# 926                                белергә батырчылык     Tatar
# 927  Бу вакытта Википедия финанслауга караганда про...    Tatar
# 928                                              Димәк    Tatar
# 929   Википедия  елның маенда ике зур премиягә лаек...    Tatar
# 930  Икенчесе  җәмгыять категориясе өчен Судьяларны...    Tatar
# 931   Википедия шулай ук Иң яхшы тәҗрибәләр Вебби п...    Tatar
# 932  нче елда brandchannelcom укучылары Википедияне...    Tatar
# 933          Бүләкне Уэльска Дэвид Вайнбергер тапшырды    Tatar
# 934  ләкләү тантанасын уздыручы Овиедодагы Астурия ...    Tatar
# 935  Күпчелек пародияләр Википедиянең ачыклыгын һәм...    Tatar
# 936  Комедияле Стивен Колберт Википедияне Колберт Р...    Tatar
# 937           акон Википедия бите бүген  тапкыр карады    Tatar
# 938                                          хезмәткәр    Tatar
# 939  чимал диетасы сөяк яман шешенең эффектын кире ...    Tatar
# 940  елның июлендә БиБиСи Радиосы Википедия пародия...    Tatar
# 941  Кайбер эскизлар турыдантуры Википедия һәм аның...    Tatar
# 942  Мультфильм Челси Элизабет Мэннингка Брэдли Эду...    Tatar
# 943                елның декабрендә Джон uliлий Норвич    Tatar
# 944  Ул аны бар булган кебек файдалы белешмәлек дип...    Tatar
# 945     Википедия шулай ук берничә кардәш проект ясады    Tatar
# 946         Бу бүтән Викимедиа проектларына Wiktionary    Tatar
# 947   Википедиянең тагын бер кардәш проекты  Wikisp...    Tatar
# 948  нче елда үзгәртелә торган сәяхәт өчен кулланма...    Tatar
# 949  Википедиянең иң ачык икътисади эффекты коммерц...    Tatar
# 950                            ЭнциклопÃдия Британника    Tatar
# 951           эчтәлек җитештерүчеләрнең эштән китүләре    Tatar
# 952  Карр язган Веб  экстатик күренешләрендә үзешчә...    Tatar
# 953  Мин куркытырлык бернәрсә дә күз алдыма китерә ...    Tatar
# 954   Башкалар Википедия яки шундый ук тырышлыклар ...    Tatar
# 955   Википедиянең биография нәшрият бизнесына йогы...    Tatar

# %%
#Counting the labels of dataframe
#we have 30 Languages in this dataframe
df_final['Language'].value_counts()
# Out:
# Dutch         1546
# Arabic        1536
# Telugu        1477
# Turkish       1474
# English       1474
# Tamil         1469
# Russian       1280
# Spanish       1245
# French        1211
# Italian       1196
# Greek         1089
# Hindi         1062
# Bulgarian     1004
# Japanese      1000
# Portugese     1000
# Indonesian    1000
# Urdu          1000
# Latin         1000
# Estonian      1000
# Swedish       1000
# Persian       1000
# Romanian      1000
# Pushto        1000
# Korean        1000
# Tatar          956
# Georgian       919
# Punjabi        908
# Danish         819
# Malayalam      594
# German         470
# Danish         428
# Kannada        369
# Name: Language, dtype: int64

# %%
df_final.isnull().sum()
#no null value we have ....
# Out:
# Text        0
# Language    0
# dtype: int64

# %%
#Counting the labels of dataframe
#we have 30 Languages in this dataframe
df_final['Language'].value_counts()
# Out:
# Dutch         1546
# Arabic        1536
# Telugu        1477
# Turkish       1474
# English       1474
# Tamil         1469
# Russian       1280
# Spanish       1245
# French        1211
# Italian       1196
# Greek         1089
# Hindi         1062
# Bulgarian     1004
# Japanese      1000
# Portugese     1000
# Indonesian    1000
# Urdu          1000
# Latin         1000
# Estonian      1000
# Swedish       1000
# Persian       1000
# Romanian      1000
# Pushto        1000
# Korean        1000
# Tatar          956
# Georgian       919
# Punjabi        908
# Danish         819
# Malayalam      594
# German         470
# Danish         428
# Kannada        369
# Name: Language, dtype: int64

# %%
#method to clean english 
import re
def remove_special_sym(df_english):
    pattern=re.compile('[^\w\s]')
    pattern1=re.compile('[\d]')
    df_english['Text']=re.sub(pattern,'',df_english['Text'])
    df_english['Text']=re.sub(pattern1,'',df_english['Text'])
    return df_english['Text']

# %%
X=np.array(df_final['Text'])

X
# Out:
# array(['Hverdagen', 'hvorpå mennesker typisk handler',
#        ' Hverdagen kan beskrives som hverdagsagtig', ...,
#        'Мин куркытырлык бернәрсә дә күз алдыма китерә алмыйм',
#        ' Башкалар Википедия яки шундый ук тырышлыклар традицион басмаларны тулысынча алыштырачак дигән фикер белән бәхәсләшәләр\nМәсәлән чыбыклы журналның баш мөхәррире Крис Андерсон Табигатьтә Википедиянең халыкның зирәклеге алымы иң югары фәнни журналларны алыштырмас',
#        ' Википедиянең биография нәшрият бизнесына йогынтысы турында даими бәхәсләр бар'],
#       dtype=object)

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
cv=TfidfVectorizer()
X=cv.fit_transform(X)
X
# Out:
# <33526x283965 sparse matrix of type '<class 'numpy.float64'>'
# 	with 978798 stored elements in Compressed Sparse Row format>

# %%
Y=np.array(df_final['Language'])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.25,random_state=2)
#random state what is

# %%
from sklearn.tree import DecisionTreeClassifier
tree_model=DecisionTreeClassifier()
tree_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
tree_model.score(x_test,y_test)*100
# Out:
# 86.90050107372942

# %%
import matplotlib.pyplot as plt
fg,ax=plt.subplots(figsize=(15,15))
from sklearn.metrics import plot_confusion_matrix
#f = plt.figure(figsize=(10,3))
cmd = plot_confusion_matrix(tree_model,x_test, y_test,cmap=plt.cm.Blues, normalize=None,xticks_rotation=65,ax=ax)
#plt.figure(figsize=(10,8))                             
plt.title('Confusion Matrix')
plt.ylabel('Actual label')
# Out:
# C:\Users\punam\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# Text(0, 0.5, 'Actual label')

# %%
y_pred=tree_model.predict(x_test)
y_pred
# Out:
# array(['Arabic', 'Arabic', 'Russian', ..., 'Georgian', 'Latin', 'Telugu'],
#       dtype=object)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix
cm = metrics.confusion_matrix(y_test, y_pred)
#print(cm)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print()

print("Precision:",metrics.precision_score(y_test, y_pred,average=None))
print()
print("Sensitivity:",metrics.recall_score(y_test, y_pred,average=None))
print()
print("F1_score:",metrics.f1_score(y_test, y_pred,average=None))
# Out:
# Accuracy: 0.8690050107372942
#
# Precision: [0.99421965 0.94300518 0.63917526 0.72195122 0.96132597 0.84334204
#  0.93534483 0.92057762 1.         0.95535714 0.99090909 1.
#  0.97580645 0.8815331  0.52380952 1.         0.97468354 0.84701493
#  1.         0.99622642 0.96326531 1.         1.         0.92657343
#  0.95779221 0.91176471 1.         0.99712644 0.25241676 1.
#  0.97256098 0.9954955 ]
#
# Sensitivity: [0.9476584  0.75518672 0.5210084  0.67579909 0.92553191 0.86827957
#  0.93133047 0.88235294 1.         0.90677966 0.88259109 0.95686275
#  0.93076923 0.87241379 0.04135338 0.82       0.88846154 0.91902834
#  0.77622378 0.98876404 0.93280632 0.87179487 0.93410853 0.9566787
#  0.86510264 0.86915888 0.98360656 0.91798942 1.         0.86871508
#  0.86920981 0.9650655 ]
#
# F1_score: [0.97038082 0.83870968 0.57407407 0.69811321 0.94308943 0.85562914
#  0.93333333 0.90106007 1.         0.93043478 0.93361884 0.97795591
#  0.95275591 0.87694974 0.07665505 0.9010989  0.92957746 0.8815534
#  0.87401575 0.9924812  0.94779116 0.93150685 0.96593186 0.94138544
#  0.90909091 0.88995215 0.99173554 0.95592287 0.40308748 0.92974589
#  0.91798561 0.98004435]

# %%
print("Enter the text more than 5 words !!!")
user=input("Enter sentense ")
data=cv.transform([user]).toarray()
y_pred=tree_model.predict(data)
y_pred
# Out:
# Enter the text more than 5 words !!!
# Enter sentense hello
# array(['Tatar'], dtype=object)
